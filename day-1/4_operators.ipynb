# %%
# Arithmetic
# Logical
# Comparison

# %%
a=10
b = 5

add_result=a+b #addiiton
sub_result=a-b #substraction
mult_result=a*b #multiplication
div_result=a/b #division
floor_div_result=a//b ## floor division

exponent_result=a**b ## floor division

print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(floor_div_result)
print(exponent_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 100000

# %%
## Comparison Operators
## == Equal to
a=10
b=10

a == b
# Out:
# True

# %%
## Not Equal to !=
a != b
# Out:
# False

# %%
# greater than >

num1=45
num2=55

num1>num2
# Out:
# False

# %%
# less than <

num1=45
num2=55

num1<num2
# Out:
# True

# %%
# greater than or equal to >=

num1=45
num2=45

num1>=num2
# Out:
# True

# %%
# less than or equal to <=

num1=45
num2=45

num1<=num2
# Out:
# True

# %%
### Logical operators
### AND OR NOT

x = True
y = True

res = x and y

print(res)
# Out:
# True

# %%
x = True
y = False

res = x or y

print(res)
# Out:
# True

# %%
x = True
y = False

res = not (x and y)

print(res)
# Out:
# True
