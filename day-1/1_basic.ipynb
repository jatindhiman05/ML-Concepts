# %%
## Multiline comment

'''
Hello jatin dhiman here
'''
# Out:
# '\nHello jatin dhiman here\n'

# %%
## Basic Syntax Rules in Python
## Case Sensitivity - Python is Case Sensitive

name="Kamal"
Name="Jatin"

print(name)
print(Name)
# Out:
# Kamal
# Jatin

# %%
## Indentation
## Python uses indentation to define block of code. Consistent use of spaces (commonly 4) or a tab is required.
## Indentation in Python is used to define the structure and hierarchy of the code. Unlike many other programming languages that use
## braces {} to delimit blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements
## within a block must be indented at the same level.

age=32
if age>30:
    print(age)
# Out:
# 32

# %%
## Single line comment
print("Hello world")
# Out:
# Hello world

# %%
## Line Continuation
## Use a backslash (\) to continue a statement to the next line
total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Multiple Statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## Understand Semantics in Python
# variable assignment
age=32
name="Jatin"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Reference
var=10
print(type(var))

var="Jatin"
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Name Error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 ## Name Error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## Code exmaple of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This wont print")
    print("This will print")
print("Outide the if block")
# Out:
# Correct Indentation
# This will print
# Outide the if block
